# %%
a=(1,2)
print("ID :",id(a))
a=(1,2)
print("ID :",id(a))
# Out:
# ID : 1556084711552
# ID : 1556084661632

# %%
a=[[1,2]]
b=dict(a)
b
# Out:
# {1: 2}

# %%
a={'a':1,'b':2}
print(list(a))
# Out:
# ['a', 'b']

# %% [markdown]
# Packages :
#
#
# constructor chaining
# methode chaining
# data types
# inbiult
#
#
#
# Question:
#
# OOPs ke Questions:
#
# merge sort
# selection sort vs insertion sort
#
#
# Fibbonacci series
# patterns
#
#
# About company
# knowledge of oops (inheritance,polymorphism,encapsulation )
#
# Introduction (formal,imformal)
#
# SQL
#
# family backgrounds
#
#
# salary bargaining
#
#
# Hr 👍
#
# why should i hire you.
#
# being engineering
