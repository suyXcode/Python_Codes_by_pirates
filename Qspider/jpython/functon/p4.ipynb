# %% [markdown]
# # Scope of Variable :
# In Python, the scope of a variable refers to the region of the program where a variable is recognized and can be accessed or modified.
#
# It defines how fast a variable can be accessed and modified.
#
# - Python follow LEGB rules
#
# **Types of Variable Scopes in Python (LEGB Rule)**
#
# | Scope Type | Full Form     | Description                                                                         | Example                          |
# | ---------- | ------------- | ----------------------------------------------------------------------------------- | -------------------------------- |
# | **L**      | **Local**     | Variables declared **inside a function**. Accessible **only within** that function. | Inside a function                |
# | **E**      | **Enclosing** | Variables in the **outer function** for **nested functions**.                       | Function inside another function |
# | **G**      | **Global**    | Declared **outside all functions**, accessible throughout the module.               | Top-level variables              |
# | **B**      | **Built-in**  | Predefined names in Python (e.g., `len`, `sum`, etc.).                              | Python’s built-in scope          |
#
#
#
# L < E < G < B
#
#
#
# | Level | Scope Name           | Description |
# |--------|----------------------|--------------|
# | 1️⃣ | **Built-in**            | Python’s predefined names (e.g., `len`, `print`, `range`) |
# | 2️⃣ | **Global**              | Names defined at the top level of a module or file |
# | 3️⃣ | **Nonlocal / Enclosed** | Names in the enclosing (outer) function scope |
# | 4️⃣ | **Local**               | Names defined inside a function or block |

# %% [markdown]
# **Global Scope Variable**
#
# - If we declare any variable in main space then it is known as global scope of variable
# - We can access global scope varible at main space as well as functional space.
# - We can not modify global scope variable inside function space/method area , in order to do that we have to use `global` keyword.

# %%
a= 10 # Global Space 
def main():
    print("Inside functional space  :",a) # global space accessed inside function
print("At main space :",a) ## Global Space outside function
main()
# Out:
# At main space : 10
# Inside functional space  : 10

# %% [markdown]
# # Local Scope :
# - If we declare a var inside a function then it is known as a local scope of variable.
# - we can not access local scope of var at main space, it can be accessed inside of the function only

# %%
def inner():
        x = "local"  # Local Scope
        print("Inner:", x)
inner()
#print("Outer:", x)  # This will raise an error because x is not defined in the global scope
# Out:
# Inner: local

# %% [markdown]
# # Enclosed / Non local Scope of Variable
#
# - If we declare any var inside nested function then it is consider as Enclosed/Non local Scope of variable.
# - We can access this eclosed var at non local and local.

# %%
#🔸 Example Demonstration (LEGB Rule)

x = "global"  # Global Scope

def outer():
    x = "enclosing"  # Enclosing Scope

    def inner():
        x = "local"  # Local Scope
        print("Inner(local space):", x)

    inner()
    print("Outer (non local space): ", x)

outer()
print("Global:", x)
# Out:
# Inner(local space): local
# Outer (non local space):  enclosing
# Global: global

# %% [markdown]
# # Non local
#
# - If we try to modify the non local variable inside the local space by default it is not possible ,in order to do that we have to use `non local` keyword.

# %% [markdown]
# # Built In Scope 👍
#
# - It is an inbuilt scope which can be accessed any module.
#
# Example : len(),print(),input() , all built in function

# %% [markdown]
# # Questions :
#
# --------------------------------------------------
#
# # what is differece between local and non local.
#
#
# | **Feature**        | **Local Variable**                                                            | **Nonlocal Variable**                                                                                                    |
# | ------------------ | ----------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------ |
# | **Definition**     | A variable declared **inside a function** and used only within that function. | A variable declared **inside a nested (inner) function**, referring to a variable in the **enclosing (outer) function**. |
# | **Scope**          | Limited to the function in which it is defined.                               | Works in nested functions; affects the outer (enclosing) function’s variable.                                            |
# | **Declared using** | Just assign normally inside a function.                                       | Declared using the `nonlocal` keyword inside an inner function.                                                          |
# | **Accessible in**  | Only inside the function where defined.                                       | Accessible to both inner and outer functions (except global).                                                            |
# | **Example**        | ```python                                                                     |                                                                                                                          |
# | def func():        |                                                                               |                                                                                                                          |
#
#
#
# 🟢 **Summary:**
# - `local` → belongs to the current function only.
# - `nonlocal` → belongs to an enclosing (outer) function, **not global**.
#
# ---
#
# ## 🌍 2️⃣ What is **Built-in Scope**?
#
# 🔹 The **built-in scope** is the **highest (outermost) level of scope** in Python.
# 🔹 It contains all the **built-in functions, exceptions, and constants** provided by Python automatically — available everywhere in your code.
#
# **Examples of built-in names:**
# ```python
# print, len, range, type, max, min, sum, abs, int, str, list

# %% [markdown]
# # ⚙️ 3️⃣ Use of global and nonlocal Keywords
# ## 🔹 global keyword
#
# **Used inside a function to modify a variable that exists outside the function (global scope).**

# %%
x = 10   # global variable

def func():
    global x   # refers to global x
    x = 20     # modifies global x

func()
print(x)  # Output: 20
# Out:
# 20

# %% [markdown]
# ➡️ Without global, x = 20 would create a new local variable instead of modifying the global one.

# %% [markdown]
# ## 🔹 nonlocal keyword
#
# Used inside nested functions to modify a variable in the enclosing (outer) function’s scope, not global.

# %%
def outer():
    y = 10
    def inner():
        nonlocal y
        y = 30
    inner()
    print(y)  # Output: 30
outer()
# Out:
# 30

# %% [markdown]
# ➡️ Without nonlocal, the assignment y = 30 would create a new local variable in the inner function.

# %% [markdown]
# | **Keyword / Scope** | **Used Where**        | **Affects Which Variable**               | **Example Context**             |
# | ------------------- | --------------------- | ---------------------------------------- | ------------------------------- |
# | **Local**           | Inside a function     | Only within that function                | Normal variable inside function |
# | **Nonlocal**        | Inside inner function | Variable from outer (enclosing) function | Nested functions                |
# | **Global**          | Inside a function     | Variable in global scope                 | Modify global variable          |
# | **Built-in**        | Everywhere            | Python’s predefined names                | `print()`, `len()` etc.         |
