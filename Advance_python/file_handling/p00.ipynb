# %%
import json
with open('students.json','r') as f:
    py_data= json.load(f)
    print(py_data)
# Out:
# {'s001': {'id': 1, 'name': 'Suyash Singh', 'age': 22, 'grade': 'A'}, 's002': {'id': 2, 'name': 'Anjali Sharma', 'age': 21, 'grade': 'B'}, 's003': {'id': 3, 'name': 'Rohit Verma', 'age': 23, 'grade': 'A'}}

# %%
import json

with open("data.json", "r") as file:
    data = json.load(file)

print(data)
# Out:
# {'name': 'Suyash', 'age': 23}

# %%
# import json

data = {"name": "Suyash", "age": 23}

with open("data.json", "w") as file:
    json.dump(data, file, indent=4)

# %%
data = {"city": "Delhi"}

with open("data.json", "a") as file:
    json.dump(data, file)

# %%
data = {"city": "Delhi"}

with open("data.json", "a") as file:
    json.dump(data, file)

# %%
# import json

# with open("data.json", "r+") as file:
#     data = json.load(file)   # read JSON
    
#     data["country"] = "India"   # modify data
    
#     file.seek(0)   # move cursor to beginning
#     json.dump(data, file, indent=4)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[8], line 4
#       1 import json
#       3 with open("data.json", "r+") as file:
# ----> 4     data = json.load(file)   # read JSON
#       6     data["country"] = "India"   # modify data
#       8     file.seek(0)   # move cursor to beginning
#
# File c:\Users\Suyash Singh\AppData\Local\Programs\Python\Python312\Lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)    291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# File c:\Users\Suyash Singh\AppData\Local\Programs\Python\Python312\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File c:\Users\Suyash Singh\AppData\Local\Programs\Python\Python312\Lib\json\decoder.py:340, in JSONDecoder.decode(self, s, _w)
#     338 end = _w(s, end).end()
#     339 if end != len(s):
# --> 340     raise JSONDecodeError("Extra data", s, end)
#     341 return obj
#
# JSONDecodeError: Extra data: line 5 column 1 (char 40)
