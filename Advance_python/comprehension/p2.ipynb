# %%
# ❓ Question

# Mark numbers as "Positive", "Negative", "Zero".

# nums = [-2, 0, 5, -1, 3]
l1 = ["positive" if i > 0 else "negative" if i < 0 else "zero" for i in [-2, 0, 5, -1, 3]]

# %%
list1=[10,20,30,40,50]

def add_values(l):
    if len(l)==0:
        return 0
    else:
        return l[0]+add_values(l[1:])
result=add_values(list1)
print(result)
# Out:
# 150

# %%
# add values of set using recursion
s1={1,2,3,4,5}
def add_set(s):
    if s==set():
        return 0
    elem=s.pop()
    return elem+add_set(s)
result2=add_set(s1)
print(result2)
# Out:
# 15
