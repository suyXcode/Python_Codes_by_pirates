# %% [markdown]
# ## zip() 👍
# - it is used to combine two or more than two attribute into a single attribute with respect to the index position.
# - deal with multiple variable of mupltiple collection in a single for loop.
#
#
#  var= zip(iterable1,iterable2,iterable3,iterable4,...........,iterablen)
#
#
#  - it combines the values and store in form of tuple.
#  - zip() return zip object
#  - attributes having shortest length will be consider

# %%
l1=[10,20,30,]
l2=[2.33,3.44,5.55,6.66,7.77]

for i,j in zip(l1,l2):
    print((i,j))
# Out:
# (10, 2.33)
# (20, 3.44)
# (30, 5.55)

# %%
l1=[10,20,30,40,50]
l2=[2.33,3.44,5.55,6.66,7.77]

for i,j in zip(l1,l2):
    print((i,j))
# Out:
# (10, 2.33)
# (20, 3.44)
# (30, 5.55)
# (40, 6.66)
# (50, 7.77)

# %% [markdown]
# ## Dictionary Function 👍
#
# - In this comprehension we convert operation into new dictionary collection.
#
# Syntax
#
# * var = {key:value for var in collection}
# * var = {key:value for var in collection if condition}
# * var ={key:value if condition else val2 for var in collection}

# %%
nums = int(input("Enter number: "))
result = {i: i*i for i in range(1, nums+1) if i%2==0}
print(result)
# Out:
# {2: 4, 4: 16, 6: 36, 8: 64, 10: 100, 12: 144}

# %%
l1=[10,20,30]
l2=["hii",["hello"],"welcome"]

print({i:j for i,j in zip(l1,l2)})
# Out:
# {10: 'hii', 20: ['hello'], 30: 'welcome'}

# %%
n = int(input("Enter number: "))
result = {i: i*i if i % 2 == 0 else i*i*i for i in range(1, n+1)}
print(result)
# Out:
# {1: 1, 2: 4, 3: 27, 4: 16, 5: 125, 6: 36, 7: 343, 8: 64, 9: 729, 10: 100, 11: 1331, 12: 144}

# %%
a = ["Texas", "California", "Florida"] # states
b = ["Austin", "Sacramento", "Tallahassee"] # capital

res = {state: capital for state, capital in zip(a, b)}
print(res)
# Out:
# {'Texas': 'Austin', 'California': 'Sacramento', 'Florida': 'Tallahassee'}

# %%
res = {num: num**3 for num in range(1, 6)}
print(res)
# Out:
# {1: 1, 2: 8, 3: 27, 4: 64, 5: 125}

# %%
a=[1,2,5]
b=[2,3,8]
res={i:j for i,j in zip(a,b)}
print(res)
# Out:
# {1: 2, 2: 3, 5: 8}

# %%
n = int(input("Enter number: "))
result = {i: i*i if i % 2 != 0 else i for i in range(1, n+1)}
print(result)
# Out:
# {1: 1, 2: 2, 3: 9, 4: 4, 5: 25, 6: 6, 7: 49, 8: 8, 9: 81, 10: 10, 11: 121, 12: 12}

# %%
n = int(input("Enter number: "))
result = {i: i*i if i % 2 != 0 else i*i*i for i in range(1, n+1)}
print(result)
# Out:
# {1: 1, 2: 8, 3: 9, 4: 64, 5: 25, 6: 216, 7: 49, 8: 512, 9: 81, 10: 1000, 11: 121, 12: 1728}

# %% [markdown]
# ## 🔥 Dictionary Comprehension in Python
#
# - Dictionary comprehension is a concise way to create dictionaries in a single line of code 🚀
#
# **📌 Syntax**
# ```python
# {key_expression: value_expression for item in iterable if condition}
# ```
#
# * key_expression → What will be the key
# * value_expression → What will be the value
# * condition → Optional filter
#
# ## ✅ 1️⃣ Basic Example
#
# - 👉 Create dictionary of numbers and their squares

# %%
squares = {i: i*i for i in range(5)}
print(squares)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}

# %% [markdown]
# ## ✅ 2️⃣ With Condition (Filtering)
#
# - 👉 Only even numbers

# %%
even_squares = {i: i*i for i in range(10) if i % 2 == 0}
print(even_squares)
# Out:
# {0: 0, 2: 4, 4: 16, 6: 36, 8: 64}

# %%
#✅ 3️⃣ Modify Existing Dictionary

marks = {"A": 70, "B": 85, "C": 90}

updated_marks = {k: v + 5 for k, v in marks.items()}
print(updated_marks)
# Out:
# {'A': 75, 'B': 90, 'C': 95}

# %%
# ✅ 4️⃣ Swap Keys and Values
data = {"a": 1, "b": 2, "c": 3}

swapped = {v: k for k, v in data.items()}
print(swapped)

#⚠️ Works only if values are unique.
# Out:
# {1: 'a', 2: 'b', 3: 'c'}

# %%
# ✅ 5️⃣ Conditional Value Assignment (If–Else)
result = {i: "Even" if i % 2 == 0 else "Odd" for i in range(6)}
print(result)
# Out:
# {0: 'Even', 1: 'Odd', 2: 'Even', 3: 'Odd', 4: 'Even', 5: 'Odd'}

# %% [markdown]
# # 🔥 Difference from Set & List Comprehension
# | Type       | Syntax         | Output Type |
# | ---------- | -------------- | ----------- |
# | List       | `[ ]`          | List        |
# | Set        | `{ }`          | Set         |
# | Dictionary | `{key: value}` | Dictionary  |

# %% [markdown]
# ## 🎯 Interview Trap
# ```python
# { i*i for i in range(5) }
#
# ```
# * 👉 This is set comprehension, not dictionary.
#
# * To create dictionary, colon : is mandatory.

# %%
n=int(input("Enter number: "))
squares = {i: i*i for i in range(1,n+1)}
print(squares)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144}

# %%
n=input("Enter string: ")
squares = {i: ord(i) for i in n}
print(squares)
# Out:
# {'a': 97, 'b': 98, 'c': 99}

# %% [markdown]
# # using loop

# %%
n=int(input("Enter number: "))
d={}
for i in range(1,n+1):
    d[i]=i*i
print(d)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
n=input("Enter string : ")
d={}    
for i in n:
    d[i]=ord(i)
print(d)
# Out:
# {'q': 113, 'w': 119, 'e': 101, 'r': 114, 't': 116, 'y': 121, 'u': 117, 'i': 105, 'o': 111, 'p': 112}

# %%
l1=[1,'hii',3.14,2,'bye',3]
print({i: i*10 for i in l1 if type(i)==int})
# Out:
# {1: 10, 2: 20, 3: 30}

# %%
l1=[1,'hii',3.14,2,'bye',3]
d={}
for i in l1:
    if type(i)==int:
        d[i]=i**10
print(d)
# Out:
# {1: 1, 2: 1024, 3: 59049}

# %%
l1=[1,'hii',3.14,2,'bye',3]
d={}
for i in l1:
    if type(i)==str:
        d[i]=len(i)
print(d)
# Out:
# {'hii': 3, 'bye': 3}

# %%
a=['python','java',3.13]
d={}
for i in a:
    if type(i)==str:
        d[i[0]+i[-1]]=i[1:-1]
print(d)
# Out:
# {'pn': 'ytho', 'ja': 'av'}

# %%
s = 'e are what we are'.split()

d1 = {word: s.count(word) for word in s}

print(d1)
# Out:
# {'e': 1, 'are': 2, 'what': 1, 'we': 1}

# %%
l1=[10,20,30,40,50]
l2=[10,20,30,40,50]
d = {i:j for i,j in zip(l1,l2)}
print(d)
