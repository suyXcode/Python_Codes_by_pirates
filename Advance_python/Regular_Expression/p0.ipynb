# %% [markdown]
# # Regular Expression :
#
# ## 🔍 What is a Regular Expression (Regex) in Python?
#
# - A Regular Expression (often called regex) is a powerful pattern-matching technique used to search, match, extract, or replace text in strings.
# - In Python, regex is handled using the built-in `re` module 🚀.
# - It is a concept by the help of which can search and match a pattern in a string.
# - It is a concept by the help of which can search and match a pattern in a string by using some expression is known as regular expression.
#
#
# **Syntax**
# ```python
# re.method_name("expression",string)
# ```

# %% [markdown]
# ## 🧠 Why Use Regular Expressions?
#
# Regex helps you:
#
# - 🔎 Search for specific patterns in text
#
# - ✂️ Extract useful data (emails, phone numbers, IDs)
#
# - 🔁 Replace or validate strings
#
# - 🧪 Validate inputs (passwords, usernames, formats)

# %% [markdown]
# ## 📦 Python Regex Module
#
# - Python provides the re module for regex operations:
#
# ```python
# import re
# ```
#
# ## 🔧 Common Regex Functions in Python
#
# | Function       | Description                             |
# | -------------- | --------------------------------------- |
# | `re.match()`   | Matches pattern at **start** of string  |
# | `re.search()`  | Searches pattern **anywhere** in string  first match|
# | `re.findall()` | Returns **all matches**                 |
# | `re.sub()`     | Replaces pattern with new text          |
# | `re.split()`   | Splits string by pattern                |
# | `re.fullmatch()` | Match entire string    |
# | `re.finditer()`  | Iterator with position |
# | `re.subn()`      | Replace + count        |
# | `re.compile()`   | Pre-compile regex      |
# | `re.escape()`    | Escape special chars   |

# %%
import re

text = "I love Python"
result = re.search("Python", text)

print(result.group())
# Out:
# Python

# %% [markdown]
# ## 🔤 Common Regex Patterns
#
# | Pattern  | Meaning                         |
# | -------- | ------------------------------- |
# | `.`      | Any single character  |
# | `^`      |  It matches at Start of string                 |
# | `$`      | It matches at End of string                   |
# | `*`      | 0 or more occurrences           |
# | `+`      | 1 or more occurrences           |
# | `?`      | 0 or 1 occurrence               |
# | `\d`     | Digit (0–9)                     |
# | `\w`     | Alphanumeric (a–z, A–Z, 0–9, _) |
# | `\s`     | Whitespace                      |
# | `[abc]`  | Any one of a, b, c              |
# | `[^abc]` | NOT a, b, or c                  |
#
#
#
# ## 🧠 Key Points to Remember
#
# - Regex is case-sensitive by default
# - Use raw strings (r"") to avoid escape issues
# - Extremely useful in data cleaning, validation, and automation

# %%
# 📌 Example: Find All Numbers
import re

text = "My roll number is 123 and code is 456"
numbers = re.findall(r"\d+", text)

print(numbers)
# Out:
# ['123', '456']

# %%
# 🔄 Example: Replace Text
import re

text = "Hello World"
new_text = re.sub("World", "Python", text)

print(new_text)
# Out:
# Hello Python

# %%
# ✅ Example: Validate Email
import re

email = "test@gmail.com"
pattern = r"^[\w\.-]+@[\w\.-]+\.\w+$"

if re.match(pattern, email):
    print("Valid Email")
else:
    print("Invalid Email")
# Out:
# Valid Email

# %%
import re
s = "cat cut cbt coot"
s1 ="python is easy to learn"
s2= "It is easy to learn python"
s3="you said python , i know python"

# %%
print(re.search("c.t",s))
print(re.search("python",s1))
print(re.search("python",s2))
print(re.search("python",s3))
# Out:
# <re.Match object; span=(0, 3), match='cat'>
# <re.Match object; span=(0, 6), match='python'>
# <re.Match object; span=(20, 26), match='python'>
# <re.Match object; span=(9, 15), match='python'>

# %%
print(re.match("c.t",s))
print(re.match("python",s1))
print(re.match("python",s2))
print(re.match("python",s3))
# Out:
# <re.Match object; span=(0, 3), match='cat'>
# <re.Match object; span=(0, 6), match='python'>
# None
# None

# %%
print(re.sub("python","java",s1))
print(re.sub("python","java",s2))
print(re.sub("python","java",s3))
# Out:
# java is easy to learn
# It is easy to learn java
# you said java , i know java

# %%
print(re.findall("c.t",s))
# Out:
# ['cat', 'cut', 'cbt']

# %% [markdown]
# ## 🔹 1. . → Any Single Character
#
# - 📌 Matches exactly ONE character (except newline \n)
# - 🧠 Think of . as: “anything here”
#
# Example

# %%
print(re.findall("h.t", "hat hot hit hut"))
# Out:
# ['hat', 'hot', 'hit', 'hut']

# %% [markdown]
# ## 🔹 2. ^ → Start of String
#
# - 📌 Ensures the pattern starts at the beginning
# - 🧠 Think of ^ as: start anchor

# %%
print(re.findall("^Hello", "Hello World"))
# Out:
# ['Hello']

# %% [markdown]
# -✅ Matches only if string starts with "Hello"
#
# ❌ Won’t match:
# ```
# "Say Hello"
#
#
# ```

# %% [markdown]
# ## 🔹 3. $ → End of String
#
# - 📌 Ensures the pattern ends at the end
# - 🧠 Think of $ as: end anchor

# %%
print(re.findall("World$", "Hello World"))
# Out:
# ['World']

# %% [markdown]
# ## 🔹 4. * → 0 or More Occurrences
#
# - 📌 Matches zero, one, or many times
# - 🧠 b* → b may appear or may not

# %%
print(re.findall("ab*", "a ab abb abbb"))
# Out:
# ['a', 'ab', 'abb', 'abbb']

# %% [markdown]
# ## 🔹 5. + → 1 or More Occurrences
#
# - 📌 Must appear at least once
# - 🧠 + means mandatory repetition

# %%
print(re.findall("ab+", "a ab abb abbb"))
#❌ "a" not included
# Out:
# ['ab', 'abb', 'abbb']

# %% [markdown]
# ## 🔹 6. ? → 0 or 1 Occurrence
#
# - 📌 Optional — appears once or not at all
# - 🧠 Perfect for optional characters
#
# Example

# %%
print(re.findall("colou?r", "color colour"))
# Out:
# ['color', 'colour']

# %% [markdown]
# ## 🔹 7. \d → Digit (0–9)
#
# - 📌 Matches any numeric digit
# - 🧠 Same as [0-9]

# %%
print(re.findall("\d", "Order 123, Code 45"))
# Out:
# ['1', '2', '3', '4', '5']
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Suyash Singh\AppData\Local\Temp\ipykernel_2176\3642052293.py:1: SyntaxWarning: invalid escape sequence '\d'
#   print(re.findall("\d", "Order 123, Code 45"))

# %% [markdown]
# **✔️ Use a raw string (r"")**

# %%
print(re.findall(r"\d", "Order 123, Code 45"))
# Out:
# ['1', '2', '3', '4', '5']

# %% [markdown]
# **⚠️ Alternative (NOT recommended)**
#
# This works because:
#
# - \\ → Python converts to \
#
# - Regex then sees \d
#
# But ❌ this is ugly and harder to read, especially in complex patterns.

# %%
print(re.findall("\\d", "Order 123, Code 45"))
# Out:
# ['1', '2', '3', '4', '5']

# %% [markdown]
# ## 🔢 {n} in Regular Expression (Regex)
# - Exactly n times
# - - Matches the preceding character or group exactly n times
#
# - 📌 It is called a quantifier
#
# **🔍 Example 1: Exact Digits**

# %%
text = "PIN: 1234"
print(re.findall(r"\d{4}", text))
# Out:
# ['1234']

# %% [markdown]
# **🧠 \d{4} → exactly 4 digits**
#
# ---
#
# **Example 2: Repeating Characters**

# %%
print(re.findall(r"a{3}", "aa aaaa aaa a"))
# Out:
# ['aaa', 'aaa']

# %% [markdown]
# **🧠 Matches only 3 a’s together**
#
# ---
#
# **🔹 Example 3: Fixed-Length Word**

# %%
print(re.findall(r"\w{5}", "Hello Python World"))
# Out:
# ['Hello', 'Pytho', 'World']

# %% [markdown]
# ### 🔥 Related Quantifiers (IMPORTANT)
#
# | Quantifier | Meaning               |
# | ---------- | --------------------- |
# | `{n}`      | Exactly n times       |
# | `{n,}`     | At least n times      |
# | `{n,m}`    | Between n and m times |

# %% [markdown]
# **🔹 {n,} → At Least n Times**

# %%
print(re.findall(r"\d{2,}", "Age 9, Code 12345"))
# Out:
# ['12345']

# %% [markdown]
# **🔹 {n,m} → Between n and m Times**

# %%
print(re.findall(r"\d{2,4}", "Years 1 12 123 12345"))
# Out:
# ['12', '123', '1234']

# %% [markdown]
# **🧠 With Groups (Very Powerful)**
# - (ab){3} → ab repeated 3 times

# %%
print(re.findall(r"(ab){3}", "ababab ab ababab"))
# Out:
# ['ab', 'ab']

# %%
print(re.findall(r"(a){2,3}", "ababab aab abaaabab"))
# Out:
# ['a', 'a']

# %% [markdown]
# **🧪 Real-World Use Cases**
#
# | Pattern          | Use             |
# | ---------------- | --------------- |
# | `\d{6}`          | OTP             |
# | `\d{10}`         | Mobile number   |
# | `[A-Z]{2}`       | State code      |
# | `[a-zA-Z0-9]{8}` | Password length |

# %% [markdown]
# ## 🔹 8. \w → Word Character
#
# - 📌 Matches:
#
#   - a–z
#   - A–Z
#   - 0–9
#   - _
# - 🧠 Used for identifiers, usernames
#
#
# Example

# %%
print(re.findall("\w", "Hello_123 World!"))
# Out:
# ['H', 'e', 'l', 'l', 'o', '_', '1', '2', '3', 'W', 'o', 'r', 'l', 'd']
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\Suyash Singh\AppData\Local\Temp\ipykernel_2176\2535620612.py:1: SyntaxWarning: invalid escape sequence '\w'
#   print(re.findall("\w", "Hello_123 World!"))

# %%
print(re.findall("\\w", "Hello_123 World!"))
# Out:
# ['H', 'e', 'l', 'l', 'o', '_', '1', '2', '3', 'W', 'o', 'r', 'l', 'd']

# %%
print(re.findall(r"\w", "Hello_123 World!"))
# Out:
# ['H', 'e', 'l', 'l', 'o', '_', '1', '2', '3', 'W', 'o', 'r', 'l', 'd']

# %%
print(re.findall(r"\w+", "Hello_123 World!"))
# Out:
# ['Hello_123', 'World']

# %% [markdown]
# ## 🔹 9. \s → Whitespace
#
# - 📌 Matches:
#
#     - Space
#     - Tab
#     - Newline
# - 🧠 Used to detect or remove spaces
#
# Example

# %%
print(re.findall("\s", "Hi there"))
# Out:
# [' ']
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Suyash Singh\AppData\Local\Temp\ipykernel_2176\2103828610.py:1: SyntaxWarning: invalid escape sequence '\s'
#   print(re.findall("\s", "Hi there"))

# %%
print(re.findall("\\s", "Hi there"))
# Out:
# [' ']

# %%
print(re.findall(r"\s", "Hi there"))
# Out:
# [' ']

# %% [markdown]
# ## 🔹 10. [abc] → Any One of a, b, or c
#
# - 📌 Matches only ONE character from set
# - 🧠 Acts like OR
#
# Example

# %%
print(re.findall("[abc]", "apple banana cherry"))
# Out:
# ['a', 'b', 'a', 'a', 'a', 'c']

# %% [markdown]
# ## 🔹 11. [^abc] → NOT a, b, or c
#
# - 📌 Matches any character except a, b, or c
# - 🧠 ^ inside [] means negation
#
# Example

# %%
print(re.findall("[^abc]", "abcXYZ"))
# Out:
# ['X', 'Y', 'Z']

# %% [markdown]
# ## 🧠 Quick Visual Summary
#
# | Symbol   | Meaning         |
# | -------- | --------------- |
# | `.`      | Any single char |
# | `^`      | Start           |
# | `$`      | End             |
# | `*`      | 0 or more       |
# | `+`      | 1 or more       |
# | `?`      | Optional        |
# | `\d`     | Digit           |
# | `\w`     | Word char       |
# | `\s`     | Space           |
# | `[abc]`  | a OR b OR c     |
# | `[^abc]` | Not a/b/c       |

# %% [markdown]
# ## ⚙ Special Sequences
#
# Special sequences begin with `\` and have specific meanings:
#
# | **Sequence** | **Meaning** |
# |--------------|-------------|
# | `\A` | Match at beginning |
# | `\b` | Word boundary |
# | `\B` | Not a word boundary |
# | `\d` | Digit (0–9) |
# | `\D` | Non-digit |
# | `\s` | Whitespace |
# | `\S` | Non-whitespace |
# | `\w` | Word character (letters/digits/underscore) |
# | `\W` | Non-word character |
# | `\Z` | End of string | :contentReference[oaicite:6]{index=6}
#
# ---

# %% [markdown]
# ## ⚙ Special Sequences
#
# Special sequences begin with `\` and have specific meanings:
#
# | **Sequence** | **Meaning** |
# |--------------|-------------|
# | `\A` | Match at beginning |
# | `\b` | Word boundary |
# | `\B` | Not a word boundary |
# | `\d` | Digit (0–9) |
# | `\D` | Non-digit |
# | `\s` | Whitespace |
# | `\S` | Non-whitespace |
# | `\w` | Word character (letters/digits/underscore) |
# | `\W` | Non-word character |
# | `\Z` | End of string | :contentReference[oaicite:6]{index=6}
#
# ---

# %% [markdown]
# ## ⚙ Special Sequences
#
# Special sequences begin with `\` and have specific meanings:
#
# | **Sequence** | **Meaning** |
# |--------------|-------------|
# | `\A` | Match at beginning |
# | `\b` | Word boundary |
# | `\B` | Not a word boundary |
# | `\d` | Digit (0–9) |
# | `\D` | Non-digit |
# | `\s` | Whitespace |
# | `\S` | Non-whitespace |
# | `\w` | Word character (letters/digits/underscore) |
# | `\W` | Non-word character |
# | `\Z` | End of string | :contentReference[oaicite:6]{index=6}
#
# ---

# %%
# replace all digits with *


text = "My password is py1234"


result = re.sub("\\d", "*", text)

print(result)
# Out:
# My password is py****

# %%
s= "hii ,this is my no 9938093651, my bro's  no. 9668816201 kelkj 5797823451 89845890701"
print(re.findall("[6-9]\\d{9}",s))
# Out:
# ['9938093651', '9668816201', '8984589070']

# %%
s="UP-65-EF-"

# %%
email = "suyash@gmail.com and sagar@yahoo.in"
pattern = r"[\w\.-]+@[\w\.-]+\.\w+"

print(re.findall(pattern, email))
# Out:
# ['suyash@gmail.com', 'sagar@yahoo.in']

# %%
pattern = r"^[\w\.-]+@[\w\.-]+\.\w+$"
print(bool(re.match(pattern, "suyash@gmail.com")))
# Out:
# True
