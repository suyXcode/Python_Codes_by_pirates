# %% [markdown]
# # User define Exception 👍
# - By extending exception class we can create our user define exception.
#
#
# **Syntax :**
#
# ```python
# class Exception_name(exception):
#     pass
#
# ```
#
# ```python
# class Exception_name(exception):
#     def __init__(self,arg1,arg2):
#         super().__init__(arg1,arg2)
# ```
#
#
# ## Raise 👍
#
# - It is used to throw the error according to user.
# - by using this `raise` keyword user can throw any error inside the code.
#
# **raise**
# ```
# raise ExceptionName("Message")
# ```
#
# ExceptionName should be standard.

# %%
print("Hello from user-defined exception handling file!")
# Out:
# Hello from user-defined exception handling file!

# %%
age = int(input("Please enter your age: "))
if age < 18:
    raise ValueError("You must be at least 18 years old to proceed.")
print("You are eligible to proceed!")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 3
#       1 age = int(input("Please enter your age: "))
#       2 if age < 18:
# ----> 3     raise ValueError("You must be at least 18 years old to proceed.")
#       4 print("You are eligible to proceed!")
#
# ValueError: You must be at least 18 years old to proceed.

# %%
class invalidAgeError(Exception):
    """Custom exception for invalid age input."""
    pass
age = int(input("Please enter your age: "))
if age < 18:
    raise invalidAgeError("You must be at least 18 years old to proceed.")
print("You are eligible to proceed!")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 4
#       2     """Custom exception for invalid age input."""
#       3     pass
# ----> 4 age = int(input("Please enter your age: "))
#       5 if age < 18:
#       6     raise invalidAgeError("You must be at least 18 years old to proceed.")
#
# ValueError: invalid literal for int() with base 10: 'iwkj'
