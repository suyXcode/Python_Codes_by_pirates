# %% [markdown]
# # Multilevel Inheritance 👍
#
# - Multilevel inheritance is a type of inheritance in which a class is derived from another derived class.
# - single level +  by considering one more level
# - In simple words:
# - **Parent → Child → Grandchild**
#
# The properties and methods flow through multiple levels.
#
# **Example:**
# Class A → Class B → Class C
#
# Class C inherits from Class B, and Class B inherits from Class A.
#
#
#
#         Multilevel Inheritance
#
#         ┌──────────┐
#         |  Parent  |
#         |   (A)    |
#         └──────────┘
#               │
#               ▼
#         ┌──────────┐
#         |  Child   |
#         |   (B)    |
#         └──────────┘
#               │
#               ▼
#         ┌──────────┐
#         |Grandchild|
#         |    (C)   |
#         └──────────┘
#
#
# ## Syntax of Multilevel Inheritance
#
#             class A:         # Parent class
#                 pass
#
#             class B(A):      # B inherits from A
#                 pass
#
#             class C(B):      # C inherits from B
#                 pass

# %%
class First:
    a=10 
    b=20 
class Second(First):
    c=30
    d=40
class Third(Second):
    e=50
    f=60
obj=Third()
print(obj.a)
print(obj.b)
print(obj.c)

print(obj.d)
print(obj.e)
print(obj.f)
# Out:
# 10
# 20
# 30
# 40
# 50
# 60

# %%
class A:
    def showA(self):
        print("This is Class A")

class B(A):
    def showB(self):
        print("This is Class B")

class C(B):
    def showC(self):
        print("This is Class C")

obj = C()
obj.showA()
obj.showB()
obj.showC()
# Out:
# This is Class A
# This is Class B
# This is Class C
